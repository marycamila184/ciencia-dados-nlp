# %% [markdown]
# # Ciência de Dados 2

# %% [markdown]
# ### Extracao de dados do Twitter

# %%
#importing libraries
import pandas as pd
import requests

# %matplotlib inline

#bearer token para acesso no twitter
TOKEN = 'Bearer '

# api-endpoints
URL_USER_LOOKUP = "https://api.twitter.com/2/users/by?"
URL_USER_TIMELINE = "https://api.twitter.com/2/users"

# %% [markdown]
# ### Para comparacao de prefeituras utilizaremos o Twitter para extracao de 3200 tweets da timeline de cada prefeitura
#
#
# ##### baseado na documentacao do twitter : https://developer.twitter.com/en/docs/twitter-api/tweets/timelines/api-reference/get-users-id-tweets
#
# ### Para a construção do dataset das prefeituras utilizamos o portal covid19.io acessando-o no dia 10/04 e filtrando pelas top 100 cidades com o maior número de obitos acumulados e buscamos manualmente o perfil de cada prefeitura nos baseando no primeiro resultado para a pesquisa "twitter prefeitura NOME_DA_CIDADE". Checamos individualmente cada uma para ter certeza de que o perfil e oficial.
#
# #### fonte casos de COVID: https://brasil.io/covid19/

# %%
# lê o arquivo CSV
df = pd.read_csv('datasets/TwitterPrefeiturasCOVIDIO.csv', delimiter=";")

# mostra o conteúdo do DataFrame
df.head()
# Out:
#          Data       Municipio  UF  Confirmados Confirmados 100k habitantes  \
# 0  05/04/2021       São Paulo  SP      635.582                    5.156,75
# 1  08/04/2021  Rio de Janeiro  RJ      235.005                    3.482,68
# 2  08/04/2021          Manaus  AM      163.021                    7.344,68
# 3  05/04/2021       Fortaleza  CE      171.154                    6.370,63
# 4  08/04/2021        Brasília  DF      311.257                   10.187,95
#
#    Obitos Letalidade Obitos 100k habitantes          perfil
# 0  22.844      3,59%                 185,34          prefsp
# 1  21.436      9,12%                 317,67  Prefeitura_Rio
# 2   8.520      5,23%                 383,86      PrefManaus
# 3   6.303      3,68%                 234,61   prefeiturapmf
# 4   6.066      1,95%                 198,55      BrasiliaDF

# %% [markdown]
# ### Algmas das prefeituras não possuem perfil no twitter então vou removê-las

# %%
df[df['perfil'] == '-']
# Out:
#           Data             Municipio  UF  Confirmados  \
# 19  05/04/2021           Santo André  SP       44.154
# 41  08/04/2021  Aparecida de Goiânia  GO       55.512
# 55  21/03/2021              Contagem  MG       22.373
# 67  05/04/2021            Piracicaba  SP       38.425
# 69  05/04/2021               Guarujá  SP       13.389
# 72  08/04/2021          Rondonópolis  MT       24.443
# 77  04/04/2021      Feira de Santana  BA       34.710
# 79  05/04/2021                 Bauru  SP       30.146
# 81  05/04/2021               Caucaia  CE       16.804
# 87  08/04/2021           Teresópolis  RJ       20.828
#
#    Confirmados 100k habitantes   Obitos Letalidade Obitos 100k habitantes  \
# 19                    6.120,87    1.712      3,88%                 237,33
# 41                    9.406,49    1.019      1,84%                 172,67
# 55                    3.344,50  818.000      3,66%                 122,28
# 67                    9.435,19  673.000      1,75%                 165,25
# 69                    4.148,41  659.000      4,92%                 204,18
# 72                   10.355,36  649.000      2,66%                 274,95
# 77                    5.601,92  608.000      1,75%                  98,13
# 79                    7.947,86  591.000      1,96%                 155,81
# 81                    4.601,16  583.000      3,47%                 159,63
# 87                   11.304,82  545.000      2,62%                 295,81
#
#    perfil
# 19      -
# 41      -
# 55      -
# 67      -
# 69      -
# 72      -
# 77      -
# 79      -
# 81      -
# 87      -

# %%
df = df[df['perfil'] != '-']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Data                         90 non-null     object
#  1   Municipio                    90 non-null     object
#  2   UF                           90 non-null     object
#  3   Confirmados                  90 non-null     float64
#  4   Confirmados 100k habitantes  90 non-null     object
#  5   Obitos                       90 non-null     float64
#  6   Letalidade                   90 non-null     object
#  7   Obitos 100k habitantes       90 non-null     object
#  8   perfil                       90 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 7.0+ KB

# %% [markdown]
# ### Antes de buscar os perfis no twitter precisamos dos IDs dos perfis para o download das timelines. Esta informação esta disponível na twitter API atraves do metodo Lookup, entao criamos uma nova coluna TwitterID
#
# ##### fonte: https://developer.twitter.com/en/docs/twitter-api/v1/accounts-and-users/follow-search-get-users/api-reference/get-users-lookup

# %%
df['TwitterID'] = 0
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Data                         90 non-null     object
#  1   Municipio                    90 non-null     object
#  2   UF                           90 non-null     object
#  3   Confirmados                  90 non-null     float64
#  4   Confirmados 100k habitantes  90 non-null     object
#  5   Obitos                       90 non-null     float64
#  6   Letalidade                   90 non-null     object
#  7   Obitos 100k habitantes       90 non-null     object
#  8   perfil                       90 non-null     object
#  9   TwitterID                    90 non-null     int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 7.7+ KB

# %%
def add_twitter_id (perfil):
    response = requests.get(url = URL_USER_LOOKUP, params = {'usernames' : perfil}, headers={'Authorization': TOKEN}, timeout=2) 
    resp_dict = response.json()
    print(resp_dict)
    first_value = resp_dict['data']
    return first_value[0]['id']

# %%
df['TwitterID'] = df.apply(lambda row : add_twitter_id(row['perfil']), axis = 1)


df
# Out:
# {'data': [{'id': '1319636844821217280', 'name': 'Cidade de São Paulo', 'username': 'prefsp'}]}
# {'data': [{'id': '1897952138', 'name': 'Prefeitura do Rio', 'username': 'Prefeitura_Rio'}]}
# {'data': [{'id': '801439438983270400', 'name': 'Prefeitura de Manaus', 'username': 'PrefManaus'}]}
# {'data': [{'id': '771896068451758084', 'name': 'Prefeitura de Fortaleza', 'username': 'prefeiturapmf'}]}
# {'data': [{'id': '24695159', 'name': 'Brasília DF', 'username': 'BrasiliaDF'}]}
# {'data': [{'id': '69284025', 'name': 'PrefSalvador', 'username': 'PrefSalvador'}]}
# {'data': [{'id': '97251131', 'name': 'Porto Alegre', 'username': 'Prefeitura_POA'}]}
# {'data': [{'id': '1305480986512293889', 'name': 'Prefeitura de Goiânia', 'username': 'prefeituradegyn'}]}
# {'data': [{'id': '1934139290', 'name': 'Prefeitura de Belém', 'username': 'prefeiturabelem'}]}
# {'data': [{'id': '68693419', 'name': 'Prefeitura Curitiba #FiqueEmCasa', 'username': 'Curitiba_PMC'}]}
# {'data': [{'id': '75342150', 'name': 'Prefeitura do Recife', 'username': 'prefrecife'}]}
# {'data': [{'id': '78922684', 'name': 'Prefeitura de BH', 'username': 'prefeiturabh'}]}
# {'data': [{'id': '864926363144400897', 'name': 'Prefeitura Guarulhos', 'username': 'PrefGru_Oficial'}]}
# {'data': [{'id': '1255541323945385986', 'name': 'Prefeitura de Campinas', 'username': 'campinaspref'}]}
# {'data': [{'id': '366188268', 'name': 'Prefeitura de Cuiabá', 'username': 'prefeitura_CBA'}]}
# {'data': [{'id': '1328704511658094596', 'name': 'prefjoaopessoa', 'username': 'prefjoaopessoa'}]}
# {'data': [{'id': '1688754422', 'name': 'Prefeitura PVH', 'username': 'prefeitura_pvh'}]}
# {'data': [{'id': '78326778', 'name': 'PrefeituraSBC', 'username': 'Prefeitura_SBC'}]}
# {'data': [{'id': '1333491825743695872', 'name': 'prefcg', 'username': 'prefcg'}]}
# {'data': [{'id': '988570400681615360', 'name': 'Prefeitura de Teresina', 'username': 'prefdeteresina'}]}
# {'data': [{'id': '55603979', 'name': 'Prefeitura de São Luís', 'username': 'PrefeituraSL'}]}
# {'data': [{'id': '60894745', 'name': 'São Gonçalo', 'username': 'prefeituraSG'}]}
# {'data': [{'id': '701171636', 'name': 'Prefeitura de Maceió', 'username': 'PrefMaceio'}]}
# {'data': [{'id': '3401430544', 'name': 'Câmara Rio Preto', 'username': 'camarariopreto'}]}
# {'data': [{'id': '84338101', 'name': 'Prefeitura de Ribeirão Preto', 'username': 'prefeituraRP'}]}
# {'data': [{'id': '1060464715', 'name': 'Prefeitura do Natal', 'username': 'NatalPrefeitura'}]}
# {'data': [{'id': '485812868', 'name': 'Uberlândia', 'username': 'PrefeituraUdia'}]}
# {'data': [{'id': '82953728', 'name': 'Prefeitura de Aracaju', 'username': 'PrefAracaju'}]}
# {'data': [{'id': '173951823', 'name': 'Câmara Municipal de Osasco', 'username': 'camara_osasco'}]}
# {'data': [{'id': '1340156732', 'name': 'Prefeitura de Niterói', 'username': 'NiteroiPref'}]}
# {'data': [{'id': '329392010', 'name': 'Prefeitura de Santos', 'username': 'santos_agora'}]}
# {'data': [{'id': '2217620418', 'name': 'Prefeitura de Nova Iguaçu', 'username': 'prefnova_iguacu'}]}
# {'data': [{'id': '344680464', 'name': 'Pref. do Jaboatão', 'username': 'jaboataoonline'}]}
# {'data': [{'id': '1072828177486098432', 'name': 'Duque de Caxias Oficial', 'username': 'duquedecaxiasof'}]}
# {'data': [{'id': '168762728', 'name': 'Prefeitura Sorocaba', 'username': 'pref_sorocaba'}]}
# {'data': [{'id': '347315965', 'name': 'Prefeitura de Canoas', 'username': 'PrefCanoas'}]}
# {'data': [{'id': '1305923250229260289', 'name': '@prefeituradejoinville', 'username': 'prefeitura_jlle'}]}
# {'data': [{'id': '1336669804862844929', 'name': 'Prefeiturabv', 'username': 'prefeiturabv'}]}
# {'data': [{'id': '1061503675', 'name': 'Prefeitura de Macapá', 'username': 'PMMacapa'}]}
# {'data': [{'id': '1336757687934197772', 'name': 'Prefeitura de Vila Velha', 'username': 'prefvilavelha'}]}
# {'data': [{'id': '1328325943585366018', 'name': 'Prefeitura de São José dos Campos', 'username': 'PrefeituraSjc'}]}
# {'data': [{'id': '1328433099076743173', 'name': 'Prefeitura de Londrina', 'username': 'preflondrina'}]}
# {'data': [{'id': '127518831', 'name': 'Prefeitura de Mauá', 'username': 'PrefeituraMaua'}]}
# {'data': [{'id': '1306633006182957056', 'name': 'prefeituraserra', 'username': 'prefeituraserra'}]}
# {'data': [{'id': '1052984598', 'name': 'Prefeitura de Juiz de Fora', 'username': 'PrefeituraJF'}]}
# {'data': [{'id': '432461172', 'name': 'Várzea Grande', 'username': 'prefeituravg'}]}
# {'data': [{'id': '18560784', 'name': 'Prefeitura de Mogi das Cruzes', 'username': 'prefeituramogi'}]}
# {'data': [{'id': '1310641080434651142', 'name': 'Prefeitura de Cariacica (ES)', 'username': 'prefcariacica'}]}
# {'data': [{'id': '1315677319596515330', 'name': 'Prefeitura de Vitória', 'username': 'vitoriaonline'}]}
# {'data': [{'id': '94634629', 'name': 'Prefeitura de Campos', 'username': 'PrefCampos'}]}
# {'data': [{'id': '92527636', 'name': 'Prefeitura de Florianópolis', 'username': 'scflorianopolis'}]}
# {'data': [{'id': '1330855278452084738', 'name': 'Prefeitura de Maringá', 'username': 'prefeiturademga'}]}
# {'data': [{'id': '237277091', 'name': 'Prefeitura Jundiaí', 'username': 'cidadedejundiai'}]}
# {'data': [{'id': '1282685463539650562', 'name': 'Prefeitura de Rio Branco', 'username': 'prefriobranco'}]}
# {'data': [{'id': '1240097651867168774', 'name': 'Secretaria da Saúde de Caxias do Sul', 'username': 'saudecaxias'}]}
# {'data': [{'id': '816283075130884097', 'name': 'Prefeitura SJM', 'username': 'SJMoficial'}]}
# {'data': [{'id': '1234815931811061760', 'name': 'Prefeitura de Santarém', 'username': 'pref_santarem'}]}
# {'data': [{'id': '1343678581151563777', 'name': 'Prefeitura de Olinda', 'username': 'pref_olinda'}]}
# {'data': [{'id': '68805739', 'name': 'Pref. Anápolis - GO', 'username': 'prefanapolis'}]}
# {'data': [{'id': '65354896', 'name': 'Prefeitura de São Vicente', 'username': 'PrefeituraSV'}]}
# {'data': [{'id': '117510515', 'name': 'Petrópolis', 'username': 'PMPetropolis'}]}
# {'data': [{'id': '1612226982', 'name': 'Pref. Campina Grande', 'username': 'PMCGoficial'}]}
# {'data': [{'id': '1328670541075640321', 'name': 'prefeituradebarueri', 'username': 'prefbarueri'}]}
# {'data': [{'id': '1241514372', 'name': 'Prefeitura de Foz', 'username': 'prefeiturafoz'}]}
# {'data': [{'id': '1332389923639468032', 'name': 'Prefeitura de Novo Hamburgo', 'username': 'PMNH_oficial'}]}
# {'data': [{'id': '257590735', 'name': 'Pref Ponta Grossa', 'username': 'prefeitura_pg'}]}
# {'data': [{'id': '1073257236175208449', 'name': 'Prefeitura de Diadema', 'username': 'PrefDiadema'}]}
# {'data': [{'id': '266140731', 'name': 'Prefeitura de GV', 'username': 'prefeituragv'}]}
# {'data': [{'id': '557810562', 'name': 'PMVROficial', 'username': 'PMVROficial'}]}
# {'data': [{'id': '132574182', 'name': 'Carapicuíba', 'username': 'carapicuibasp'}]}
# {'data': [{'id': '3115006793', 'name': 'Prefeitura ITZ', 'username': 'PrefeituraITZ'}]}
# {'data': [{'id': '402816322', 'name': 'Prefeitura de Pelotas', 'username': 'PrefPelotas'}]}
# {'data': [{'id': '76184001', 'name': 'prefeitura cascavel', 'username': 'PrefdeCascavel'}]}
# {'data': [{'id': '1510324140', 'name': 'Prefeitura Paulista', 'username': 'prefpaulista'}]}
# {'data': [{'id': '106480080', 'name': 'Pref. de Ananindeua', 'username': 'PrefAnanindeua'}]}
# {'data': [{'id': '213717283', 'name': 'Prefeitura Alvorada', 'username': 'prefalvorada'}]}
# {'data': [{'id': '475823125', 'name': 'Prefeitura Gravataí', 'username': 'gravatai_rs'}]}
# {'data': [{'id': '1354859334', 'name': 'Prefeitura de Betim', 'username': 'Prefeitur_Betim'}]}
# {'data': [{'id': '78678910', 'name': 'Prefeitura de Chapecó', 'username': 'prefechapeco'}]}
# {'data': [{'id': '1905478651', 'name': 'PMI ITAQUAQUECETUBA', 'username': 'pmi_itaqua'}]}
# {'data': [{'id': '90463409', 'name': 'São Caetano do Sul', 'username': 'Prefeitura_SCS'}]}
# {'data': [{'id': '256638145', 'name': 'Taboão da Serra', 'username': 'pmtsoficial'}]}
# {'data': [{'id': '306335041', 'name': 'Prefeitura de Itajaí', 'username': 'pref_itajai'}]}
# {'data': [{'id': '100562702', 'name': 'Prefeitura Itaboraí', 'username': 'pmitaborai'}]}
# {'data': [{'id': '77380339', 'name': 'são josé dos pinhais', 'username': 'pmsjp'}]}
# {'data': [{'id': '52928395', 'name': 'Prefeitura Itabuna', 'username': 'itabunaba'}]}
# {'data': [{'id': '1334501712355332097', 'name': 'Prefeitura de Caruaru', 'username': 'prefcaruaru'}]}
# {'data': [{'id': '2724530988', 'name': 'Prefeitura de Viamão', 'username': 'pmviamao'}]}
# {'data': [{'id': '270941106', 'name': 'Prefeitura de Sobral', 'username': 'governodesobral'}]}
# {'data': [{'id': '1249117465', 'name': 'Prefeitura Araçatuba', 'username': 'AracatubaPMA'}]}
#           Data       Municipio  UF  Confirmados Confirmados 100k habitantes  \
# 0   05/04/2021       São Paulo  SP      635.582                    5.156,75
# 1   08/04/2021  Rio de Janeiro  RJ      235.005                    3.482,68
# 2   08/04/2021          Manaus  AM      163.021                    7.344,68
# 3   05/04/2021       Fortaleza  CE      171.154                    6.370,63
# 4   08/04/2021        Brasília  DF      311.257                   10.187,95
# ..         ...             ...  ..          ...                         ...
# 95  04/04/2021         Itabuna  BA       27.502                   12.870,35
# 96  08/04/2021         Caruaru  PE       18.799                    5.146,49
# 97  09/04/2021          Viamão  RS        6.754                    2.635,17
# 98  05/04/2021          Sobral  CE       18.679                    8.864,75
# 99  05/04/2021       Araçatuba  SP       19.142                    9.661,38
#
#      Obitos Letalidade Obitos 100k habitantes           perfil  \
# 0    22.844      3,59%                 185,34           prefsp
# 1    21.436      9,12%                 317,67   Prefeitura_Rio
# 2     8.520      5,23%                 383,86       PrefManaus
# 3     6.303      3,68%                 234,61    prefeiturapmf
# 4     6.066      1,95%                 198,55       BrasiliaDF
# ..      ...        ...                    ...              ...
# 95  490.000      1,78%                 229,31        itabunaba
# 96  490.000      2,61%                 134,14      prefcaruaru
# 97  490.000      7,25%                 191,18         pmviamao
# 98  481.000      2,58%                 228,27  governodesobral
# 99  475.000      2,48%                 239,74     AracatubaPMA
#
#               TwitterID
# 0   1319636844821217280
# 1            1897952138
# 2    801439438983270400
# 3    771896068451758084
# 4              24695159
# ..                  ...
# 95             52928395
# 96  1334501712355332097
# 97           2724530988
# 98            270941106
# 99           1249117465
#
# [90 rows x 10 columns]

# %%
## Salvando os IDs das prefeituras para nao precisar fazer de novo a cada execucao do notebook
df.to_csv('datasets/TwitterPrefsComID.csv', sep=';', encoding='utf-8')

# %% [markdown]
# ### Extracao da timeline de cada prefeitura

# %% [markdown]
# #### Extraimos um .json com todas as informacoes referentes as prefeituras para futuras analises.

# %%
import json

infoprefeituras = [];

# %%
def get_twitter_information (twitterid, municipio):
    url = URL_USER_TIMELINE + "/" + twitterid + "/tweets?"
    pagination_token = ''
    
    all_tweets=[]
    all_includes=[]
    
    params = {'tweet.fields' : 'created_at,public_metrics,referenced_tweets' , 'expansions' : 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id' , 'user.fields' : 'created_at' ,'max_results' : '100'}
    
    while True:
        if pagination_token != '':
            params = {'tweet.fields' : 'created_at,entities,public_metrics,referenced_tweets' , 'expansions' : 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id' , 'user.fields' : 'created_at' ,'max_results' : '100', 'pagination_token' : pagination_token}
            
        response = requests.get(url = url, params = params, headers={'Authorization': TOKEN}, timeout=2) 
        resp_dict = response.json()
        
        if 'meta' in resp_dict:
            meta_value = resp_dict['meta']

            if meta_value['result_count'] > 0 :
                tweet_values = resp_dict['data']
                includes_value = resp_dict['includes']

                all_tweets.append(tweet_values)
                all_includes.append(includes_value)

                if 'next_token' in meta_value:
                    pagination_token = meta_value['next_token']

                else:
                    print("Nao ha next_token - Acabou as paginas")
                    print("Params")
                    print(params)
                    print("Municipio")
                    print(municipio)
                    print("Mensagem da API")
                    print(meta_value)
                    pagination_token = ''
                    break;


            else:
                print("Nao ha mais tweets - Result count 0")
                print("Params")
                print(params)
                print("Municipio")
                print(municipio)
                print("Mensagem da API")
                print(resp_dict)
                pagination_token = ''
                break;
                
        else:
            print("Ocorreu um erro e a API nao retornou nenhum tweet")
            print("Params")
            print(params)
            print("Municipio")
            print(municipio)
            print("Mensagem da API")
            print(resp_dict)
            break;
    
    infoprefeituras.append({'municipio' : municipio, 'tweets' : all_tweets, 'includes' : all_includes})
    
    return True;

# %%
df['Processado'] = df.apply(lambda row : get_twitter_information(row['TwitterID'], row['Municipio']), axis = 1)

## Salvando os resultados para consulta futura
df.to_csv('datasets/TwitterPrefsCOVIDComID.csv', sep=';', encoding='utf-8')

## Salvando o json file.

with open('PrefsTwitter.json', 'w') as jsonfile:
    json.dump(infoprefeituras, jsonfile)
# Out:
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29gqowa4ywr2huy85nrzslwgmu'}
# Municipio
# São Paulo
# Mensagem da API
# {'oldest_id': '1333409812378423298', 'newest_id': '1334180572374110208', 'result_count': 40, 'previous_token': '77qpymm88g5h9vqkluldpw91lqdm5qvs70vee16t8p7w8'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29aeat5me042ndvmgy4meihmig'}
# Municipio
# Rio de Janeiro
# Mensagem da API
# {'oldest_id': '1330628934476713985', 'newest_id': '1331673998485286913', 'result_count': 41, 'previous_token': '77qpymm88g5h9vqkluldppwd2de24oaq07wiabb5q7ayb'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n2xurtrwac9ljw4d6j7e95celo2'}
# Municipio
# Manaus
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '77qpymm88g5h9vqkluceeaa6iwfc458t4plv574h6u9f5'}}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nntnl5p5oprb7wpgyakf6v7ixoaf'}
# Municipio
# Fortaleza
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xaen39emocrgrie3nuekbt22xje46'}}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n2spf8h56hbi7zdaqgs1ejy69rue'}
# Municipio
# Brasília
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9x9tm53henuj0yigrhmkry0qtkvho5'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n3sekewf941a4ii03kzwo69tr8w'}
# Municipio
# Salvador
# Mensagem da API
# {'oldest_id': '1052894729820663808', 'newest_id': '1059551976202088453', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqklucf8u2610j10jkaocc9r81afzjn7'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w33pvcemreutv16mp242e1aqk34'}
# Municipio
# Porto Alegre
# Mensagem da API
# {'oldest_id': '1352710123450322945', 'newest_id': '1353664733593935874', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqklulek5dp5mwep2kos8b06k6ncq2ic'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29gqzilygv4bffxeinoh79jn01'}
# Municipio
# Goiânia
# Mensagem da API
# {'oldest_id': '1333385222910603267', 'newest_id': '1334247380691128321', 'result_count': 24, 'previous_token': '77qpymm88g5h9vqkluldpw9c84r65gw9hyt12y0tm0e9d'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nkqhz6v5mhtwh5cv1d0pzb65rt4k'}
# Municipio
# Belém
# Mensagem da API
# {'oldest_id': '710946176154075138', 'newest_id': '710946176154075138', 'result_count': 1, 'previous_token': '10iy0xk016rrqp9xabjxlbyont0ngt7v62cow7hf3faw'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t50g9wrk1dht4c6kqc60vw95s1h'}
# Municipio
# Curitiba
# Mensagem da API
# {'meta': {'result_count': 0, 'next_token': '7140dibdnow9c7btw3t4lj6a11evcuz80v2d7hmwc96wo', 'previous_token': '77qpymm88g5h9vqkluiggvryune6ahmnif721en9hf6eu'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t226l8oxw35uy30up8wzxwpcwmu'}
# Municipio
# Recife
# Mensagem da API
# {'oldest_id': '1219308682913239040', 'newest_id': '1220345047847178246', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluidim3lfy0udgu8qndfaa0z1lzjq'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n3rzn0wk63r7favuv0otueqnju9'}
# Municipio
# Belo Horizonte
# Mensagem da API
# {'oldest_id': '1051140506061864961', 'newest_id': '1052605163213545473', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqklucf8f5dkjwsi0r1qnxjf748k4xmb'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nnssqp6i4a7px6cc9z2nayih7inm'}
# Municipio
# Guarulhos
# Mensagem da API
# {'oldest_id': '868183558925451264', 'newest_id': '869923543127076864', 'result_count': 17, 'previous_token': '10iy0xk016rrqp9xaeltslel3eigzuwuxt7jp9r662wk'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t469b6k8o28grjkf59faid0woqf'}
# Municipio
# Campinas
# Mensagem da API
# {'oldest_id': '1257392164344074247', 'newest_id': '1275506634018762753', 'result_count': 98, 'previous_token': '77qpymm88g5h9vqkluifmotj6oawakanqxijnm0kvg0fn'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nnpupmf05tiziglb25esbvcny88i'}
# Municipio
# Cuiabá
# Mensagem da API
# {'oldest_id': '798135986240811008', 'newest_id': '801534221491859460', 'result_count': 41, 'previous_token': '10iy0xk016rrqp9xaejaduqrx1xg7gdjfex1ta14easw'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29gss34cv0o2rdisbucyld214n'}
# Municipio
# João Pessoa
# Mensagem da API
# {'oldest_id': '1333377626547818496', 'newest_id': '1334621757752233985', 'result_count': 38, 'previous_token': '77qpymm88g5h9vqkluldpwajarqcu6pu46zhlau39a791'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nhr56ml162e7kyeqp9egbxy6i1x4'}
# Municipio
# Porto Velho
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa8kkuviju43nvfsxldecy4tl3rqv'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '9557owtzx4m9b4ehltzvsrec2jtgf1x'}
# Municipio
# São Bernardo do Campo
# Mensagem da API
# {'oldest_id': '4472244398', 'newest_id': '4636542690', 'result_count': 17, 'previous_token': '9drmqzx45lch5m3jp1vb9wvulzqndbk'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29rfti0i7j3l6da9qs79k52qsw'}
# Municipio
# Campo Grande
# Mensagem da API
# {'oldest_id': '1333492164886720513', 'newest_id': '1338938663820988418', 'result_count': 12, 'previous_token': '77qpymm88g5h9vqkluldq4ucaxtd6etpz3d5x5y764zzs'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t181qmszk9w552bp9qva7xublfa'}
# Municipio
# Teresina
# Mensagem da API
# {'oldest_id': '1201429656731291648', 'newest_id': '1203014054371102721', 'result_count': 36, 'previous_token': '77qpymm88g5h9vqkluicoh8zjzp9qjccsfhkkb7jml2k1'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3q58oh9yucjy23c0ovmjwxnkf8ds'}
# Municipio
# São Luís
# Mensagem da API
# {'oldest_id': '1195023738598768646', 'newest_id': '1195355780444123136', 'result_count': 9, 'previous_token': '77qpymm88g5h9vqklufgp3zmlam94s7oc10yvxolaf1h2'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# São Gonçalo
# Mensagem da API
# {'oldest_id': '2889645590', 'newest_id': '3123887550', 'result_count': 11}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n3d2kanx8gxxcyusm86bexcjho1'}
# Municipio
# Maceió
# Mensagem da API
# {'oldest_id': '1044597407810342912', 'newest_id': '1046448104851955713', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluceti1qu24w4b6m5b2uu6pt16wxf'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nhrkozon0ceobpjsigj7sk6e39dc'}
# Municipio
# São José do Rio Preto
# Mensagem da API
# {'oldest_id': '628223339623018496', 'newest_id': '636171096417562629', 'result_count': 72, 'previous_token': '10iy0xk016rrqp9xa8l0d8m5njcyhp1hz5p39v9otph5'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13netwl074k3q01d0adenphkpr57hs'}
# Municipio
# Ribeirão Preto
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa5nc994n85fgbueh9inm3rl5qx4p'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t2hr3o0x67apihz3axonnwqa1pz'}
# Municipio
# Natal
# Mensagem da API
# {'oldest_id': '1237070194826260481', 'newest_id': '1237130151642763270', 'result_count': 10, 'previous_token': '77qpymm88g5h9vqkluidy6m0rxb7595vaimnqeg1rtmpc'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t22aue13xx8191f0w00d4gcnq5u'}
# Municipio
# Uberlândia
# Mensagem da API
# {'oldest_id': '1219669958814326785', 'newest_id': '1222155326507683840', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluidiqcg79tjkw3iq1offmm2s7n00'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t46hslezgxp388hcmlf0mhnrdbk'}
# Municipio
# Aracaju
# Mensagem da API
# {'oldest_id': '1278112150473584641', 'newest_id': '1279079116285902848', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluifmxay4i9ksaqk0qqhi4hzs9zjs'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n8tifme7w5zl9lhpdv0w7weyv1a0'}
# Municipio
# Osasco
# Mensagem da API
# {'oldest_id': '365459056095277058', 'newest_id': '365572148443619328', 'result_count': 17, 'previous_token': '10iy0xk016rrqp9x9zmy3vbqjsbzhkrkuohxnl9ni4hk'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t3by3lfhxzr3qrj6xh5651oc5yw'}
# Municipio
# Niterói
# Mensagem da API
# {'oldest_id': '1254082265891639297', 'newest_id': '1255614897808986112', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluiesdly6hvjqujt5pcqqpcbg9y5u'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t2hc7s6va1c51697bfva8rs8uux'}
# Municipio
# Santos
# Mensagem da API
# {'oldest_id': '1230508293359054854', 'newest_id': '1230539261209907201', 'result_count': 7, 'previous_token': '77qpymm88g5h9vqkluidxrq4wd06kskdikegu9kme84s1'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nbrlek6p6kg4y03ewybrg4zglph0'}
# Municipio
# Nova Iguaçu
# Mensagem da API
# {'oldest_id': '406092979103748098', 'newest_id': '420537260837064705', 'result_count': 21, 'previous_token': '10iy0xk016rrqp9xa2l12t47ue9hww564imohgf1f12t'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nhrkee5asap0khocyenyfv6bniux'}
# Municipio
# Jaboatão dos Guararapes
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa8l02n2tgceguz2juinv221q98oo'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n51eamoszbacqld2ps9csmd8ppu'}
# Municipio
# Duque de Caxias
# Mensagem da API
# {'oldest_id': '1074623626819895297', 'newest_id': '1080513736324964352', 'result_count': 28, 'previous_token': '77qpymm88g5h9vqklucghrpga4t9oivhdugcsizeqxzqq'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n1obsyyfie000fphs3gcdazntpu'}
# Municipio
# Sorocaba
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '77qpymm88g5h9vqklucd4rbbpfndujpcpu7fe58mu3hgx'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t2hr3d6z6i8fdes3g23e7rre1py'}
# Municipio
# Canoas
# Mensagem da API
# {'oldest_id': '1230590023411564544', 'newest_id': '1236642393732124678', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluidy4ism99wun80u828mz5b64ojc'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29grvyxr75lbbygaktoxnki0j6'}
# Municipio
# Joinville
# Mensagem da API
# {'oldest_id': '1333396458100436993', 'newest_id': '1334558330845601792', 'result_count': 9, 'previous_token': '77qpymm88g5h9vqkluldpwa8mxpqwdm3qkb3qffs3qa7m'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w3itbygxr48mc2cdcm0i7flycdy'}
# Municipio
# Boa Vista
# Mensagem da API
# {'oldest_id': '1338473321277624321', 'newest_id': '1361355726053142530', 'result_count': 98, 'previous_token': '77qpymm88g5h9vqklulez6pad8fze4hqby2svqwlgbhv4'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t2wjzcpjbnb81ehfm79xmh4o56c'}
# Municipio
# Macapá
# Mensagem da API
# {'oldest_id': '1241024545307398144', 'newest_id': '1241861937945772049', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqkluieczhpgj98cshegwdah8hop7321'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29rem7rzvcf5jpfwvozifb2jaq'}
# Municipio
# Vila Velha
# Mensagem da API
# {'oldest_id': '1336775864957218816', 'newest_id': '1339244776881795073', 'result_count': 15, 'previous_token': '77qpymm88g5h9vqkluldq6wyyrx7qw47m9x0kqneg0chf'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w3itarkd9rdhmvx3ygesdznre44'}
# Municipio
# São José dos Campos
# Mensagem da API
# {'oldest_id': '1328419460546441217', 'newest_id': '1362098357259411465', 'result_count': 79, 'previous_token': '77qpymm88g5h9vqklulez8t4bdenyx7rtfojp3hzezcxh'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29aciesa13muh2b82zbat2e0xh'}
# Municipio
# Londrina
# Mensagem da API
# {'oldest_id': '1328437372116213760', 'newest_id': '1330987992916353029', 'result_count': 51, 'previous_token': '77qpymm88g5h9vqkluldpnsjbv133uaq9abqb0jt8itkp'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-208-f2044f3fa83b> in <module>
# ----> 1 df['Processado'] = df.apply(lambda row : get_twitter_information(row['TwitterID'], row['Municipio']), axis = 1)
#       2
#       3 ## Salvando os resultados para consulta futura
#       4 df.to_csv('datasets/TwitterPrefsCOVIDComID.csv', sep=';', encoding='utf-8')
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7543             kwds=kwds,
#    7544         )
# -> 7545         return op.get_result()
#    7546
#    7547     def applymap(self, func) -> "DataFrame":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-208-f2044f3fa83b> in <lambda>(row)
# ----> 1 df['Processado'] = df.apply(lambda row : get_twitter_information(row['TwitterID'], row['Municipio']), axis = 1)
#       2
#       3 ## Salvando os resultados para consulta futura
#       4 df.to_csv('datasets/TwitterPrefsCOVIDComID.csv', sep=';', encoding='utf-8')
#       5
#
# <ipython-input-207-bc64c7a6e0ad> in get_twitter_information(twitterid, municipio)
#      15         resp_dict = response.json()
#      16
# ---> 17         meta_value = resp_dict['meta']
#      18
#      19         if meta_value['result_count'] > 0 :
#
# KeyError: 'meta'

# %% [markdown]
# ### Na linha 42 deu algum erro na extracao, porem para nao ultrapassar o limite de tweets por conta (500 000 - neste momento ja estou com 233 400) decido cortar o dataframe e continuar a parte da cidade 42 (Londrina)
#
# ### Update: O erro era que a prefeitura de Maua nao esta com o perfil publico (nao sei qual o sentido de ter uma conta de prefeitura no twitter sem ser aberta para o publico)

# %%
dfCidRestantes = df.iloc[42:90]
dfCidRestantes
# Out:
#           Data              Municipio  UF  Confirmados  \
# 44  05/04/2021                   Mauá  SP       17.815
# 45  08/04/2021                  Serra  ES       49.410
# 46  21/03/2021           Juiz de Fora  MG       22.278
# 47  08/04/2021          Várzea Grande  MT       20.937
# 48  05/04/2021        Mogi das Cruzes  SP       19.646
# 49  08/04/2021              Cariacica  ES       30.538
# 50  08/04/2021                Vitória  ES       43.288
# 51  08/04/2021  Campos dos Goytacazes  RJ       20.680
# 52  08/04/2021          Florianópolis  SC       70.797
# 53  08/04/2021                Maringá  PR       41.586
# 54  05/04/2021                Jundiaí  SP       30.916
# 56  03/04/2021             Rio Branco  AC       32.329
# 57  09/04/2021          Caxias do Sul  RS       38.386
# 58  08/04/2021     São João de Meriti  RJ        7.061
# 59  08/04/2021               Santarém  PA       16.397
# 60  08/04/2021                 Olinda  PE       16.766
# 61  08/04/2021               Anápolis  GO       27.487
# 62  05/04/2021            São Vicente  SP       13.059
# 63  08/04/2021             Petrópolis  RJ        7.467
# 64  04/04/2021         Campina Grande  PB       24.151
# 65  05/04/2021                Barueri  SP       19.776
# 66  08/04/2021          Foz do Iguaçu  PR       33.372
# 68  09/04/2021          Novo Hamburgo  RS       19.899
# 70  08/04/2021           Ponta Grossa  PR       28.689
# 71  05/04/2021                Diadema  SP       17.613
# 73  21/03/2021   Governador Valadares  MG       17.803
# 74  08/04/2021          Volta Redonda  RJ       23.102
# 75  05/04/2021            Carapicuíba  SP       20.136
# 76  05/04/2021             Imperatriz  MA       13.152
# 78  09/04/2021                Pelotas  RS       21.208
# 80  08/04/2021               Cascavel  PR       31.318
# 82  08/04/2021               Paulista  PE        7.776
# 83  08/04/2021             Ananindeua  PA       17.265
# 84  09/04/2021               Alvorada  RS       15.507
# 85  09/04/2021               Gravataí  RS       15.232
# 86  21/03/2021                  Betim  MG       19.445
# 88  08/04/2021                Chapecó  SC       31.619
# 89  05/04/2021        Itaquaquecetuba  SP       10.472
# 90  05/04/2021     São Caetano do Sul  SP       13.097
# 91  05/04/2021        Taboão da Serra  SP       13.744
# 92  08/04/2021                 Itajaí  SC       21.702
# 93  08/04/2021               Itaboraí  RJ        7.435
# 94  08/04/2021   São José dos Pinhais  PR       17.767
# 95  04/04/2021                Itabuna  BA       27.502
# 96  08/04/2021                Caruaru  PE       18.799
# 97  09/04/2021                 Viamão  RS        6.754
# 98  05/04/2021                 Sobral  CE       18.679
# 99  05/04/2021              Araçatuba  SP       19.142
#
#    Confirmados 100k habitantes  Obitos Letalidade Obitos 100k habitantes  \
# 44                    3.730,48   949.0      5,33%                 198,72
# 45                    9.371,44   941.0      1,90%                 178,48
# 46                    3.886,03   929.0      4,17%                 162,05
# 47                    7.281,78   927.0      4,43%                 322,41
# 48                    4.358,18   913.0      4,65%                 202,54
# 49                    7.954,32   909.0      2,98%                 236,77
# 50                   11.832,01   872.0      2,01%                 238,35
# 51                    4.045,64   853.0      4,12%                 166,87
# 52                   13.913,79   852.0      1,20%                 167,44
# 53                    9.667,63   846.0      2,03%                 196,67
# 54                    7.308,64   825.0      2,67%                 195,03
# 56                    7.819,93   790.0      2,44%                 191,09
# 57                    7.418,29   779.0      2,03%                 150,55
# 58                    1.493,11   756.0     10,71%                 159,86
# 59                    5.350,10   747.0      4,56%                 243,74
# 60                    4.264,91   710.0      4,23%                 180,61
# 61                    7.016,07   708.0      2,58%                 180,72
# 62                    3.545,22   705.0      5,40%                 191,39
# 63                    2.434,80   694.0      9,29%                  226,3
# 64                    5.864,64   691.0      2,86%                  167,8
# 65                    7.139,81   687.0      3,47%                 248,03
# 66                   12.922,46   679.0      2,03%                 262,93
# 68                    8.055,23   667.0      3,35%                 270,01
# 70                    8.073,77   656.0      2,29%                 184,61
# 71                    4.127,17   654.0      3,71%                 153,25
# 73                    6.334,55   625.0      3,51%                 222,38
# 74                    8.431,76   622.0      2,69%                 227,02
# 75                    4.994,26   618.0      3,07%                 153,28
# 76                    5.071,39   615.0      4,68%                 237,14
# 78                    6.180,71   595.0      2,81%                  173,4
# 80                    9.423,68   590.0      1,88%                 177,53
# 82                    2.325,53   583.0      7,50%                 174,35
# 83                    3.223,81   580.0      3,36%                  108,3
# 84                    7.337,05   575.0      3,71%                 272,06
# 85                    5.370,57   566.0      3,72%                 199,56
# 86                    4.371,78   552.0      2,84%                 124,11
# 88                   14.114,81   544.0      1,72%                 242,84
# 89                    2.792,45   522.0      4,98%                  139,2
# 90                    8.086,71   516.0      3,94%                  318,6
# 91                    4.680,37   502.0      3,65%                 170,95
# 92                    9.726,95   500.0      2,30%                  224,1
# 93                    3.065,44   497.0      6,68%                 204,91
# 94                    5.399,35   495.0      2,79%                 150,43
# 95                   12.870,35   490.0      1,78%                 229,31
# 96                    5.146,49   490.0      2,61%                 134,14
# 97                    2.635,17   490.0      7,25%                 191,18
# 98                    8.864,75   481.0      2,58%                 228,27
# 99                    9.661,38   475.0      2,48%                 239,74
#
#              perfil            TwitterID  Processado
# 44   PrefeituraMaua            127518831        True
# 45  prefeituraserra  1306633006182957056        True
# 46     PrefeituraJF           1052984598        True
# 47     prefeituravg            432461172        True
# 48   prefeituramogi             18560784        True
# 49    prefcariacica  1310641080434651142        True
# 50    vitoriaonline  1315677319596515330        True
# 51       PrefCampos             94634629        True
# 52  scflorianopolis             92527636        True
# 53  prefeiturademga  1330855278452084738        True
# 54  cidadedejundiai            237277091        True
# 56    prefriobranco  1282685463539650562        True
# 57      saudecaxias  1240097651867168774        True
# 58       SJMoficial   816283075130884097        True
# 59    pref_santarem  1234815931811061760        True
# 60      pref_olinda  1343678581151563777        True
# 61     prefanapolis             68805739        True
# 62     PrefeituraSV             65354896        True
# 63     PMPetropolis            117510515        True
# 64      PMCGoficial           1612226982        True
# 65      prefbarueri  1328670541075640321        True
# 66    prefeiturafoz           1241514372        True
# 68     PMNH_oficial  1332389923639468032        True
# 70    prefeitura_pg            257590735        True
# 71      PrefDiadema  1073257236175208449        True
# 73     prefeituragv            266140731        True
# 74      PMVROficial            557810562        True
# 75    carapicuibasp            132574182        True
# 76    PrefeituraITZ           3115006793        True
# 78      PrefPelotas            402816322        True
# 80   PrefdeCascavel             76184001        True
# 82     prefpaulista           1510324140        True
# 83   PrefAnanindeua            106480080        True
# 84     prefalvorada            213717283        True
# 85      gravatai_rs            475823125        True
# 86  Prefeitur_Betim           1354859334        True
# 88     prefechapeco             78678910        True
# 89       pmi_itaqua           1905478651        True
# 90   Prefeitura_SCS             90463409        True
# 91      pmtsoficial            256638145        True
# 92      pref_itajai            306335041        True
# 93       pmitaborai            100562702        True
# 94            pmsjp             77380339        True
# 95        itabunaba             52928395        True
# 96      prefcaruaru  1334501712355332097        True
# 97         pmviamao           2724530988        True
# 98  governodesobral            270941106        True
# 99     AracatubaPMA           1249117465        True

# %%
dfCidRestantes['Processado'] = dfCidRestantes.apply(lambda row : get_twitter_information(row['TwitterID'], row['Municipio']), axis = 1)

## Salvando o json file.
with open('PrefsTwitter.json', 'w') as jsonfile:
    json.dump(infoprefeituras, jsonfile)
# Out:
# Ocorreu um erro e a API nao retornou nenhum tweet
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Mauá
# Mensagem da API
# {'errors': [{'resource_id': '127518831', 'parameter': 'id', 'resource_type': 'user', 'section': 'data', 'title': 'Authorization Error', 'value': '127518831', 'detail': 'Sorry, you are not authorized to see the user with id: [127518831].', 'type': 'https://api.twitter.com/2/problems/not-authorized-for-resource'}]}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w2ofy5dbzcmxpsjp07yhoo1viup'}
# Municipio
# Serra
# Mensagem da API
# {'oldest_id': '1333377875320446977', 'newest_id': '1340984313551200257', 'result_count': 68, 'previous_token': '77qpymm88g5h9vqklule4teh8wdu64x71xq9i2rturhvb'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nqqwd4h2f0rvupnj70ibn3i0koxe'}
# Municipio
# Juiz de Fora
# Mensagem da API
# {'oldest_id': '927864234368819201', 'newest_id': '936568198601814017', 'result_count': 50, 'previous_token': '10iy0xk016rrqp9xahkc1degjeryxmmpypt76kk0j587'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Várzea Grande
# Mensagem da API
# {'meta': {'result_count': 0}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '506yuzpqzgpcu3j2ryif7gron87a4qvoqhwe2pip11'}
# Municipio
# Mogi das Cruzes
# Mensagem da API
# {'oldest_id': '91979087484170241', 'newest_id': '99125204298641408', 'result_count': 50, 'previous_token': '54wwr7vi60j36xghscrxsre97yt9wgfg85h0oi0cag'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29pask96aurlzis6y24jtnl1rm'}
# Municipio
# Cariacica
# Mensagem da API
# {'oldest_id': '1333365541885644801', 'newest_id': '1338571765358977031', 'result_count': 33, 'previous_token': '77qpymm88g5h9vqkluldq4t5b9bapba4ezvvdkqmht7ap'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29pbzmy9yx1c62lv6cneg0ab75'}
# Municipio
# Vitória
# Mensagem da API
# {'oldest_id': '1334219323305549827', 'newest_id': '1338952339856756748', 'result_count': 85, 'previous_token': '77qpymm88g5h9vqkluldq4ucdxs0fnxfm66zz8jz2my48'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3q2pmlo3zax3sust9xlmjvjcf60o'}
# Municipio
# Campos dos Goytacazes
# Mensagem da API
# {'oldest_id': '1122967479364538369', 'newest_id': '1133855633722236930', 'result_count': 73, 'previous_token': '77qpymm88g5h9vqklufe6240qfknci26rj5a0nyp33ei8'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nhsua45w1yqdd3kc7ip928ph233n'}
# Municipio
# Florianópolis
# Mensagem da API
# {'oldest_id': '668059897045610496', 'newest_id': '668493751992627200', 'result_count': 2, 'previous_token': '10iy0xk016rrqp9xa8m9ycsnt9cuomf22egmz9n9vkts'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29en5m13sdbjmjz7eziphfyvqp'}
# Municipio
# Maringá
# Mensagem da API
# {'oldest_id': '1330872650302943234', 'newest_id': '1333524903857954822', 'result_count': 62, 'previous_token': '77qpymm88g5h9vqkluldpu5id11ddthw20biwukt3uvjm'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n51gh5g71bu21jfcrx1f21p5lbn'}
# Municipio
# Jundiaí
# Mensagem da API
# {'oldest_id': '1075119831907778561', 'newest_id': '1082704009901813766', 'result_count': 50, 'previous_token': '77qpymm88g5h9vqklucghvzi452i5a7v35eobikgr0bp2'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t50e4w5weix6vzojhsxjwlua1iv'}
# Municipio
# Rio Branco
# Mensagem da API
# {'oldest_id': '1284225406682497025', 'newest_id': '1292223143197671425', 'result_count': 52, 'previous_token': '77qpymm88g5h9vqkluiggtmcaiw7s63ywdr2srlssg9x1'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Caxias do Sul
# Mensagem da API
# {'oldest_id': '1240101249678180359', 'newest_id': '1263532535956504577', 'result_count': 71}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nnrjqzv4hdptfnilmrecfqi74379'}
# Municipio
# São João de Meriti
# Mensagem da API
# {'oldest_id': '819560848700145666', 'newest_id': '848930367813898240', 'result_count': 64, 'previous_token': '10iy0xk016rrqp9xaekzf8sn5f9vwk1cp5zapmsvbfw0'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3t3brp4hoel6zxnvulq6a7u1vh9y'}
# Municipio
# Santarém
# Mensagem da API
# {'oldest_id': '1234817740042575872', 'newest_id': '1252581792282009602', 'result_count': 34, 'previous_token': '77qpymm88g5h9vqkluies77h8oc30if0sazkhcrlldtma'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Olinda
# Mensagem da API
# {'oldest_id': '1348644013356810241', 'newest_id': '1381001326155472896', 'result_count': 84}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n5sw8eicp48srojouj80k0bds2es'}
# Municipio
# Anápolis
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9x9wmbwnfvd5y925xvqn7x676sds8j'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nersszzbc9tyo8v6tdngicmjteeq'}
# Municipio
# São Vicente
# Mensagem da API
# {'oldest_id': '535387087462465536', 'newest_id': '536579945087373314', 'result_count': 19, 'previous_token': '10iy0xk016rrqp9xa5l8h8m96x1ggqbnaazu5zdw61is'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n2rumy6pmjjnx9hpnors322rbbjo'}
# Municipio
# Petrópolis
# Mensagem da API
# {'oldest_id': '108189134438412288', 'newest_id': '111090800250732544', 'result_count': 22, 'previous_token': '10iy0xk016rrqp9x9tlab6tke88lvv3ze5m9ihmy31h0'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nbsvel5kr81mriefgtmqplggeiia'}
# Municipio
# Campina Grande
# Mensagem da API
# {'oldest_id': '459778423670710273', 'newest_id': '459778423670710273', 'result_count': 1, 'previous_token': '10iy0xk016rrqp9xa2mb2u31xhwxn1lmql6ssp4agks3'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29rgf4fdhznsistyrh50y8e8fk'}
# Municipio
# Barueri
# Mensagem da API
# {'oldest_id': '1328674414624452610', 'newest_id': '1339693324710625296', 'result_count': 92, 'previous_token': '77qpymm88g5h9vqkluldq6y6c2bg9h3y1hcfbnlufajp2'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n8reh6sz235fvdy5vp41ox7dydrm'}
# Municipio
# Foz do Iguaçu
# Mensagem da API
# {'oldest_id': '308595543691632640', 'newest_id': '312675962020048896', 'result_count': 67, 'previous_token': '10iy0xk016rrqp9x9zku5fqhpxg3xpgo37tlejqfspx2'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3w29n5rey039cw7vcsllffnardwz'}
# Municipio
# Novo Hamburgo
# Mensagem da API
# {'oldest_id': '1333431467851063297', 'newest_id': '1337427255342084096', 'result_count': 42, 'previous_token': '77qpymm88g5h9vqkluldq2o45y533wjlu3czrsohy6912'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '506yuzpqzgpcu3j2pudmxn1kf0kgffa3yqzoedqer4'}
# Municipio
# Ponta Grossa
# Mensagem da API
# {'oldest_id': '41229892712534016', 'newest_id': '43418136933974016', 'result_count': 14, 'previous_token': '54wwr7vi60j36xghq8n4mlwmv0zl8xae1qwb5uk9x2'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '7140dibdnow9c7btw3n51ijs738kqv0ihswqb5b7tq2ih'}
# Municipio
# Diadema
# Mensagem da API
# {'oldest_id': '1073266488826564610', 'newest_id': '1082709120896155650', 'result_count': 17, 'previous_token': '77qpymm88g5h9vqklucghvzi464xv9w78vmkaveioz228'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '506yuzpqzgpcu3j2q9ng8463zhjgn816bimv6pts1c'}
# Municipio
# Governador Valadares
# Mensagem da API
# {'oldest_id': '47742239056740352', 'newest_id': '55004236995497984', 'result_count': 69, 'previous_token': '54wwr7vi60j36xghqnwytmdkxux2zw7reg2xaxg5dg'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n5v02j5b8moa3glo8klrw9xh5cfq'}
# Municipio
# Volta Redonda
# Mensagem da API
# {'oldest_id': '291508306915246080', 'newest_id': '296327625310347264', 'result_count': 59, 'previous_token': '10iy0xk016rrqp9x9wofqs2sf4cge6hz9xgtecrihc8k'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '1t0l2p5hbfkua73b0qw9f2ah257tuz7sl'}
# Municipio
# Carapicuíba
# Mensagem da API
# {'oldest_id': '14862197566', 'newest_id': '18678757734', 'result_count': 16, 'previous_token': '1upwhrzfhjrspzx57ls94tamw1jjfxxkk'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nhu3kji2n2v5tzeghleh214eo8xf'}
# Municipio
# Imperatriz
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa8nj8sflb4km4gsndpedo7zt9yr6'}}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nersx7mvf39lxhirvagbn8q1gdo0'}
# Municipio
# Pelotas
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa5l8lgke34z27ywyreg89flg23ax'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Cascavel
# Mensagem da API
# {'oldest_id': '4158845117', 'newest_id': '4158845117', 'result_count': 1}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nbqr5gfijb7bgaejrwu4t120uddi'}
# Municipio
# Paulista
# Mensagem da API
# {'oldest_id': '345502109808078848', 'newest_id': '401070647813869568', 'result_count': 58, 'previous_token': '10iy0xk016rrqp9xa2k6togqyhfi8zy85ulmdlt0nz94'}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n5s1x6mimm38i4avxlyemwhklf7c'}
# Municipio
# Ananindeua
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9x9wlhlfk1ansoslp2tpyb93cz7513'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Alvorada
# Mensagem da API
# {'oldest_id': '2049215173758976', 'newest_id': '2049215173758976', 'result_count': 1}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n5ukodzxelfdui2oml5vb8ne7ltg'}
# Municipio
# Gravataí
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9x9wo0cmxg2n4u4zgvip5rxfistbn7'}}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nht8yol7aj8s4wh87egqzs228o4w'}
# Municipio
# Betim
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa8momxipyky8fdvf3ignlyxgudrt'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nht9dldmafxh9jill5sn0t5244kw'}
# Municipio
# Chapecó
# Mensagem da API
# {'oldest_id': '673889496023240704', 'newest_id': '677556439926329346', 'result_count': 50, 'previous_token': '10iy0xk016rrqp9xa8mp1ub1wtjfk16iz9o1xr1sia7q'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nbqre0txgdpdqnt5pqlsqy2v3x2q'}
# Municipio
# Itaquaquecetuba
# Mensagem da API
# {'oldest_id': '405821722613800960', 'newest_id': '405821722613800960', 'result_count': 1, 'previous_token': '10iy0xk016rrqp9xa2k729rg4feu14fg6oides71401c'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '9557owtzx4m9b4ehndh15ww0zna46yd'}
# Municipio
# São Caetano do Sul
# Mensagem da API
# {'oldest_id': '5773647506', 'newest_id': '6769074516', 'result_count': 94, 'previous_token': '9drmqzx45lch5m3jqlchq6c70df3rjq'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Taboão da Serra
# Mensagem da API
# {'oldest_id': '40502551287836672', 'newest_id': '86472976249266176', 'result_count': 47}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13n2rup4elhmdy6pe505f3o5cw741g'}
# Municipio
# Itajaí
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9x9tladdc45o3eh6sbw9f0ac8astv7'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': '1t0l2p5hbfkua73b0qqvyb5xdjhnb6muo'}
# Municipio
# Itaboraí
# Mensagem da API
# {'oldest_id': '9926388026', 'newest_id': '11887256723', 'result_count': 17, 'previous_token': '1upwhrzfhjrspzx57lmvk9uqdvuxixv77'}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# São José dos Pinhais
# Mensagem da API
# {'oldest_id': '4385498336', 'newest_id': '4385498336', 'result_count': 1}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nnr46fch3sfl6924jncyino4652v'}
# Municipio
# Itabuna
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xaekjuo9zru51gqgbfrcv4ujiruwm'}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Caruaru
# Mensagem da API
# {'oldest_id': '1351216021764534273', 'newest_id': '1380664152952295429', 'result_count': 32}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100', 'pagination_token': 'zldjwdz3w6sba13nhr5npl1ehjcudsifr72cr254d9y'}
# Municipio
# Viamão
# Mensagem da API
# {'meta': {'result_count': 0, 'previous_token': '10iy0xk016rrqp9xa8klbyik2j8t4v6pbv6yyxxjq33p'}}
# Nao ha mais tweets - Result count 0
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Sobral
# Mensagem da API
# {'meta': {'result_count': 0}}
# Nao ha next_token - Acabou as paginas
# Params
# {'tweet.fields': 'created_at,entities,public_metrics,referenced_tweets', 'expansions': 'author_id,referenced_tweets.id,entities.mentions.username,referenced_tweets.id.author_id', 'user.fields': 'created_at', 'max_results': '100'}
# Municipio
# Araçatuba
# Mensagem da API
# {'oldest_id': '363663236085714944', 'newest_id': '372830203783163904', 'result_count': 49}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Extracao dos dados realizada. Agora vamos limpar os dados para analisa-los
