# %% [markdown]
# # Ciência de Dados 2

# %% [markdown]
# ### Limpeza dos dados do Twitter
#
# ##### fonte: https://towardsdatascience.com/preprocessing-text-data-using-python-576206753c28

# %%
import pandas as pd
import numpy as np
import joblib
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')
# nltk.download('mac_morpho')
# nltk.download('rslp')
# nltk.download('omw')
# nltk.download('floresta')

import string
import fasttext
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem.snowball import SnowballStemmer
import unicodedata
import re

pd.options.mode.chained_assignment = None
pd.set_option('display.max_colwidth', 100)
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Mary
# [nltk_data]     Camila\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Mary
# [nltk_data]     Camila\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Mary Camila\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# lê o arquivo CSV
df = pd.read_csv('datasets/PrefsTweetsAgregado.csv', delimiter=";")

# mostra o conteúdo do DataFrame
df.head()
# Out:
#    Unnamed: 0  municipio             tweet_id                created_at  \
# 0           0  São Paulo  1380999403910094855  2021-04-10T21:41:30.000Z
# 1           1  São Paulo  1380985859059576832  2021-04-10T20:47:40.000Z
# 2           2  São Paulo  1380969544513159176  2021-04-10T19:42:51.000Z
# 3           3  São Paulo  1380960415555915781  2021-04-10T19:06:34.000Z
# 4           4  São Paulo  1380953886299713541  2021-04-10T18:40:38.000Z
#
#              author_id  \
# 0  1319636844821217280
# 1  1319636844821217280
# 2  1319636844821217280
# 3  1319636844821217280
# 4  1319636844821217280
#
#                                                                                                   text  \
# 0  Esse da foto é o Pluto, um filhote calminho e super brincalhão. Ele e seus irmãos estão a espera...
# 1  O início da vacinação dos idosos com 67 anos ou mais foi antecipado para segunda (12). A estimat...
# 2  RT @spsmdet: Uma onda de solidariedade chegou ao Banco de Alimentos!\n\nNo primeiro semestre de ...
# 3  A Secretaria de Educação divulgou a convocação de 55 candidatos aprovados no concurso público pa...
# 4  Os postos drive-thru que fazem parte da estrutura da campanha de vacinação contra a Covid-19 na ...
#
#    public_metrics_retweet_count  public_metrics_reply_count  \
# 0                             4                           0
# 1                             0                           1
# 2                             2                           0
# 3                             0                           0
# 4                             1                           0
#
#    public_metrics_like_count  public_metrics_quote_count  referenced_twitter
# 0                          9                           0               False
# 1                          1                           0               False
# 2                          0                           0                True
# 3                          2                           0               False
# 4                          3                           0               False

# %% [markdown]
# ### Checando os dados verificamos que todos os tweets possuem o author_id da propria prefeitura, quando o tweet e uma resposta ou é retweetado entao temos a ultima coluna para confirmar. Por enquanto decido dropar a coluna author_id. A outra coluna foi resultado da agregação dos dados do Twitter então remove ela também.

# %%
df.drop('author_id', axis=1, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167919 entries, 0 to 167918
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   municipio                     167919 non-null  object
#  1   tweet_id                      167919 non-null  int64
#  2   created_at                    167919 non-null  object
#  3   text                          167919 non-null  object
#  4   public_metrics_retweet_count  167919 non-null  int64
#  5   public_metrics_reply_count    167919 non-null  int64
#  6   public_metrics_like_count     167919 non-null  int64
#  7   public_metrics_quote_count    167919 non-null  int64
#  8   referenced_twitter            167919 non-null  bool
# dtypes: bool(1), int64(5), object(3)
# memory usage: 10.4+ MB

# %% [markdown]
# ### Faço a filtragem pelo ano de 2020 e 2021 para ter certeza que estaremos com tweets dentro da pandemia

# %%
df['created_at'] = pd.to_datetime(df['created_at']).dt.date

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto é o Pluto, um filhote calminho e super brincalhão. Ele e seus irmãos estão a espera...
# 1  O início da vacinação dos idosos com 67 anos ou mais foi antecipado para segunda (12). A estimat...
# 2  RT @spsmdet: Uma onda de solidariedade chegou ao Banco de Alimentos!\n\nNo primeiro semestre de ...
# 3  A Secretaria de Educação divulgou a convocação de 55 candidatos aprovados no concurso público pa...
# 4  Os postos drive-thru que fazem parte da estrutura da campanha de vacinação contra a Covid-19 na ...
#
#    public_metrics_retweet_count  public_metrics_reply_count  \
# 0                             4                           0
# 1                             0                           1
# 2                             2                           0
# 3                             0                           0
# 4                             1                           0
#
#    public_metrics_like_count  public_metrics_quote_count  referenced_twitter
# 0                          9                           0               False
# 1                          1                           0               False
# 2                          0                           0                True
# 3                          2                           0               False
# 4                          3                           0               False

# %% [markdown]
# ## A data do primeiro boletim da pandemia é 25/02/2020 então filtro os tweets a aprtir desta data

# %%
df = df[(df['created_at'] >= pd.Timestamp(year=2020, month=2, day=25))]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71273 entries, 0 to 165191
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   municipio                     71273 non-null  object
#  1   tweet_id                      71273 non-null  int64
#  2   created_at                    71273 non-null  object
#  3   text                          71273 non-null  object
#  4   public_metrics_retweet_count  71273 non-null  int64
#  5   public_metrics_reply_count    71273 non-null  int64
#  6   public_metrics_like_count     71273 non-null  int64
#  7   public_metrics_quote_count    71273 non-null  int64
#  8   referenced_twitter            71273 non-null  bool
# dtypes: bool(1), int64(5), object(3)
# memory usage: 5.0+ MB

# %% [markdown]
# ## Checando o numero de cidades que restaram

# %%
df.groupby('municipio').size().count()
# Out:
# 59

# %% [markdown]
# ### Observando o tutorial que esta na fonte, tem uma parte com contrações e idioma devido ao tutorial ser para a língua inglesa, então decido pular essa parte pois todas as prefeituras são do Brasil.

# %% [markdown]
# ### Removo também os acentos do texto do tweet.

# %%
def remove_punctuations(text):
    # Unicode normalize transforma um caracter em seu equivalente em latin.
    nfkd = unicodedata.normalize('NFKD', text)
    wordNew = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    return re.sub('[^a-zA-Z0-9 \\\]', '', wordNew)

def remove_numbers(text):
    return re.sub(" \d+", " ", text)

df['text'] = df['text'].apply(remove_punctuations)
df['text'] = df['text'].apply(remove_numbers)
df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#    public_metrics_retweet_count  public_metrics_reply_count  \
# 0                             4                           0
# 1                             0                           1
# 2                             2                           0
# 3                             0                           0
# 4                             1                           0
#
#    public_metrics_like_count  public_metrics_quote_count  referenced_twitter
# 0                          9                           0               False
# 1                          1                           0               False
# 2                          0                           0                True
# 3                          2                           0               False
# 4                          3                           0               False

# %% [markdown]
# ### Agora faco a tokenizacao

# %%
df['tokens'] = df['text'].apply(word_tokenize, language='portuguese')

df = df[['municipio', 'tweet_id', 'created_at', 'text', 'tokens', 'referenced_twitter', 'public_metrics_retweet_count', 'public_metrics_reply_count', 'public_metrics_like_count', 'public_metrics_quote_count' ]]

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [Esse, da, foto, e, o, Pluto, um, filhote, calminho, e, super, brincalhao, Ele, e, seus, irmaos,...
# 1  [O, inicio, da, vacinacao, dos, idosos, com, anos, ou, mais, foi, antecipado, para, segunda, A, ...
# 2  [RT, spsmdet, Uma, onda, de, solidariedade, chegou, ao, Banco, de, AlimentosNo, primeiro, semest...
# 3  [A, Secretaria, de, Educacao, divulgou, a, convocacao, de, candidatos, aprovados, no, concurso, ...
# 4  [Os, postos, drivethru, que, fazem, parte, da, estrutura, da, campanha, de, vacinacao, contra, a...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %% [markdown]
# ### Agora com a parte de texto pronta, vou aplicar algumas modificações para limpeza. A primeira sera deixar tudo em minusculo.

# %%
df['tokens'] = df['tokens'].apply(lambda x: [word.lower() for word in x])

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [esse, da, foto, e, o, pluto, um, filhote, calminho, e, super, brincalhao, ele, e, seus, irmaos,...
# 1  [o, inicio, da, vacinacao, dos, idosos, com, anos, ou, mais, foi, antecipado, para, segunda, a, ...
# 2  [rt, spsmdet, uma, onda, de, solidariedade, chegou, ao, banco, de, alimentosno, primeiro, semest...
# 3  [a, secretaria, de, educacao, divulgou, a, convocacao, de, candidatos, aprovados, no, concurso, ...
# 4  [os, postos, drivethru, que, fazem, parte, da, estrutura, da, campanha, de, vacinacao, contra, a...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %% [markdown]
# ### Agora retiro parte da pontuacao e depois removo os acentos.

# %%
punc = string.punctuation
df['tokens'] = df['tokens'].apply(lambda x: [word for word in x if word not in punc])

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [esse, da, foto, e, o, pluto, um, filhote, calminho, e, super, brincalhao, ele, e, seus, irmaos,...
# 1  [o, inicio, da, vacinacao, dos, idosos, com, anos, ou, mais, foi, antecipado, para, segunda, a, ...
# 2  [rt, spsmdet, uma, onda, de, solidariedade, chegou, ao, banco, de, alimentosno, primeiro, semest...
# 3  [a, secretaria, de, educacao, divulgou, a, convocacao, de, candidatos, aprovados, no, concurso, ...
# 4  [os, postos, drivethru, que, fazem, parte, da, estrutura, da, campanha, de, vacinacao, contra, a...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
## Agora retiro as stop words

stop_words = set(stopwords.words('portuguese'))
df['tokens'] = df['tokens'].apply(lambda x: [word for word in x if word not in stop_words])

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [foto, pluto, filhote, calminho, super, brincalhao, irmaos, estao, espera, familia, cheia, amor,...
# 1  [inicio, vacinacao, idosos, anos, antecipado, segunda, estimativa, pessoas, nessa, faixa, etaria...
# 2  [rt, spsmdet, onda, solidariedade, chegou, banco, alimentosno, primeiro, semestre, arrecadados, ...
# 3  [secretaria, educacao, divulgou, convocacao, candidatos, aprovados, concurso, publico, professor...
# 4  [postos, drivethru, fazem, parte, estrutura, campanha, vacinacao, contra, covid19, cidade, sao, ...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
## Agora retiro os links

df['tokens'] = df['tokens'].apply(lambda x: [word for word in x if "http" not in word ])

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [foto, pluto, filhote, calminho, super, brincalhao, irmaos, estao, espera, familia, cheia, amor,...
# 1  [inicio, vacinacao, idosos, anos, antecipado, segunda, estimativa, pessoas, nessa, faixa, etaria...
# 2  [rt, spsmdet, onda, solidariedade, chegou, banco, alimentosno, primeiro, semestre, arrecadados, ...
# 3  [secretaria, educacao, divulgou, convocacao, candidatos, aprovados, concurso, publico, professor...
# 4  [postos, drivethru, fazem, parte, estrutura, campanha, vacinacao, contra, covid19, cidade, sao, ...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
## Gero uma frase somente com os tokens
df['tokens_frase'] = df['tokens'].apply(lambda tokens: ' '.join(tokens))

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [foto, pluto, filhote, calminho, super, brincalhao, irmaos, estao, espera, familia, cheia, amor,...
# 1  [inicio, vacinacao, idosos, anos, antecipado, segunda, estimativa, pessoas, nessa, faixa, etaria...
# 2  [rt, spsmdet, onda, solidariedade, chegou, banco, alimentosno, primeiro, semestre, arrecadados, ...
# 3  [secretaria, educacao, divulgou, convocacao, candidatos, aprovados, concurso, publico, professor...
# 4  [postos, drivethru, fazem, parte, estrutura, campanha, vacinacao, contra, covid19, cidade, sao, ...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count  \
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
#
#                                                                                           tokens_frase
# 0  foto pluto filhote calminho super brincalhao irmaos estao espera familia cheia amor cosap adotar...
# 1  inicio vacinacao idosos anos antecipado segunda estimativa pessoas nessa faixa etaria recebam pr...
# 2  rt spsmdet onda solidariedade chegou banco alimentosno primeiro semestre arrecadados toneladas alim
# 3  secretaria educacao divulgou convocacao candidatos aprovados concurso publico professores educac...
# 4  postos drivethru fazem parte estrutura campanha vacinacao contra covid19 cidade sao paulo estara...

# %% [markdown]
# ### Agora comeco o processo de stemming.

# %% [markdown]
# #### Update : Fiz um primeiro com com a nltk.tag.pos_tag porem a biblioteca nao e boa para classificacao em portugues, so funciona para o ingles. Entao baixei uma pos_tagger ja treinada para poder finalizar o processo de lematização
#
#
# #### Udate: Tentei utilizar alguns modelos pre treinados mas nao consegui termnar a tempo entao decido usar stemming que ja esta pronto para portugues

# %%
## df['pos_tag'] = df['tokens'].apply(nltk.tag.pos_tag)

## def get_wordnet_pos(tag):
##     if tag.startswith('J'):
##         return wn.ADJ
##     elif tag.startswith('V'):
##         return wn.VERB
##     elif tag.startswith('V'):
##         return wn.VERB
##     elif tag.startswith('N'):
##         return wn.NOUN
##     elif tag.startswith('R'):
##         return wn.ADV
##     elif tag.startswith('R'):
##         return wn.ADV
##     else:
##        return wn.NOUN
    
##  df['wordnet_pos'] = df['pos_tag'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

##  wnl = WordNetLemmatizer()

##  df['final_tokens'] = df['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

# %%
stemmer = SnowballStemmer("portuguese");

df['final_tokens'] = df['tokens'].apply(lambda x: [stemmer.stem(word) for word in x])

df.head()
# Out:
#    municipio             tweet_id  created_at  \
# 0  São Paulo  1380999403910094855  2021-04-10
# 1  São Paulo  1380985859059576832  2021-04-10
# 2  São Paulo  1380969544513159176  2021-04-10
# 3  São Paulo  1380960415555915781  2021-04-10
# 4  São Paulo  1380953886299713541  2021-04-10
#
#                                                                                                   text  \
# 0  Esse da foto e o Pluto um filhote calminho e super brincalhao Ele e seus irmaos estao a espera d...
# 1  O inicio da vacinacao dos idosos com  anos ou mais foi antecipado para segunda  A estimativa e q...
# 2  RT spsmdet Uma onda de solidariedade chegou ao Banco de AlimentosNo primeiro semestre de  foram ...
# 3  A Secretaria de Educacao divulgou a convocacao de  candidatos aprovados no concurso publico para...
# 4  Os postos drivethru que fazem parte da estrutura da campanha de vacinacao contra a Covid19 na ci...
#
#                                                                                                 tokens  \
# 0  [foto, pluto, filhote, calminho, super, brincalhao, irmaos, estao, espera, familia, cheia, amor,...
# 1  [inicio, vacinacao, idosos, anos, antecipado, segunda, estimativa, pessoas, nessa, faixa, etaria...
# 2  [rt, spsmdet, onda, solidariedade, chegou, banco, alimentosno, primeiro, semestre, arrecadados, ...
# 3  [secretaria, educacao, divulgou, convocacao, candidatos, aprovados, concurso, publico, professor...
# 4  [postos, drivethru, fazem, parte, estrutura, campanha, vacinacao, contra, covid19, cidade, sao, ...
#
#    referenced_twitter  public_metrics_retweet_count  \
# 0               False                             4
# 1               False                             0
# 2                True                             2
# 3               False                             0
# 4               False                             1
#
#    public_metrics_reply_count  public_metrics_like_count  \
# 0                           0                          9
# 1                           1                          1
# 2                           0                          0
# 3                           0                          2
# 4                           0                          3
#
#    public_metrics_quote_count  \
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
#
#                                                                                           tokens_frase  \
# 0  foto pluto filhote calminho super brincalhao irmaos estao espera familia cheia amor cosap adotar...
# 1  inicio vacinacao idosos anos antecipado segunda estimativa pessoas nessa faixa etaria recebam pr...
# 2  rt spsmdet onda solidariedade chegou banco alimentosno primeiro semestre arrecadados toneladas alim
# 3  secretaria educacao divulgou convocacao candidatos aprovados concurso publico professores educac...
# 4  postos drivethru fazem parte estrutura campanha vacinacao contra covid19 cidade sao paulo estara...
#
#                                                                                           final_tokens
# 0  [fot, plut, filhot, calminh, sup, brincalha, irma, esta, esper, famil, che, amor, cosap, adot, p...
# 1  [inici, vacinaca, idos, anos, antecip, segund, estim, pesso, ness, faix, etar, receb, primeir, d...
# 2    [rt, spsmdet, onda, solidariedad, cheg, banc, alimentosn, primeir, semestr, arrecad, tonel, alim]
# 3  [secret, educaca, divulg, convocaca, candidat, aprov, concurs, public, professor, educaca, infan...
# 4  [post, drivethru, faz, part, estrutur, campanh, vacinaca, contr, covid19, cidad, sao, paul, esta...

# %%
df.to_csv('datasets/PrefsTweetsLimpoStemmerSB.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71273 entries, 0 to 165191
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   municipio                     71273 non-null  object
#  1   tweet_id                      71273 non-null  int64
#  2   created_at                    71273 non-null  object
#  3   text                          71273 non-null  object
#  4   tokens                        71273 non-null  object
#  5   referenced_twitter            71273 non-null  bool
#  6   public_metrics_retweet_count  71273 non-null  int64
#  7   public_metrics_reply_count    71273 non-null  int64
#  8   public_metrics_like_count     71273 non-null  int64
#  9   public_metrics_quote_count    71273 non-null  int64
#  10  tokens_frase                  71273 non-null  object
#  11  final_tokens                  71273 non-null  object
# dtypes: bool(1), int64(5), object(6)
# memory usage: 6.6+ MB

# %% [markdown]
# ### Salvo a versao final dos tweets ja pre-processados e prontos para a analise
